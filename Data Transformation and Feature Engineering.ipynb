# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('/content/data-income-age-group.csv');
df
# Out:
#         Name  Age  Income($)
# 0        Rob   27      70000
# 1    Michael   29      90000
# 2      Mohan   29      61000
# 3     Ismail   28      60000
# 4       Kory   42     150000
# 5     Gautam   39     155000
# 6      David   41     160000
# 7     Andrea   38     162000
# 8       Brad   36     156000
# 9   Angelina   35     130000
# 10    Donald   37     137000
# 11       Tom   26      45000
# 12    Arnold   27      48000
# 13     Jared   28      51000
# 14     Stark   29      49500
# 15    Ranbir   32      53000
# 16    Dipika   40      65000
# 17  Priyanka   41      63000
# 18      Nick   43      64000
# 19      Alia   39      80000
# 20       Sid   41      82000
# 21     Abdul   39      58000

# %%
df.copy()
column=['Age', 'Income($)']
features= df_scaled[column]
features
# Out:
#     Age  Income($)
# 0    27      70000
# 1    29      90000
# 2    29      61000
# 3    28      60000
# 4    42     150000
# 5    39     155000
# 6    41     160000
# 7    38     162000
# 8    36     156000
# 9    35     130000
# 10   37     137000
# 11   26      45000
# 12   27      48000
# 13   28      51000
# 14   29      49500
# 15   32      53000
# 16   40      65000
# 17   41      63000
# 18   43      64000
# 19   39      80000
# 20   41      82000
# 21   39      58000

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

df_scaled[column] = scaler.fit_transform(features.values)
df_scaled
# Out:
#         Name       Age  Income($)
# 0        Rob  0.058824   0.213675
# 1    Michael  0.176471   0.384615
# 2      Mohan  0.176471   0.136752
# 3     Ismail  0.117647   0.128205
# 4       Kory  0.941176   0.897436
# 5     Gautam  0.764706   0.940171
# 6      David  0.882353   0.982906
# 7     Andrea  0.705882   1.000000
# 8       Brad  0.588235   0.948718
# 9   Angelina  0.529412   0.726496
# 10    Donald  0.647059   0.786325
# 11       Tom  0.000000   0.000000
# 12    Arnold  0.058824   0.025641
# 13     Jared  0.117647   0.051282
# 14     Stark  0.176471   0.038462
# 15    Ranbir  0.352941   0.068376
# 16    Dipika  0.823529   0.170940
# 17  Priyanka  0.882353   0.153846
# 18      Nick  1.000000   0.162393
# 19      Alia  0.764706   0.299145
# 20       Sid  0.882353   0.316239
# 21     Abdul  0.764706   0.111111

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(5,10))
df_scaled[column] = scaler.fit_transform(features.values)
df_scaled
# Out:
#         Name        Age  Income($)
# 0        Rob   5.294118   6.068376
# 1    Michael   5.882353   6.923077
# 2      Mohan   5.882353   5.683761
# 3     Ismail   5.588235   5.641026
# 4       Kory   9.705882   9.487179
# 5     Gautam   8.823529   9.700855
# 6      David   9.411765   9.914530
# 7     Andrea   8.529412  10.000000
# 8       Brad   7.941176   9.743590
# 9   Angelina   7.647059   8.632479
# 10    Donald   8.235294   8.931624
# 11       Tom   5.000000   5.000000
# 12    Arnold   5.294118   5.128205
# 13     Jared   5.588235   5.256410
# 14     Stark   5.882353   5.192308
# 15    Ranbir   6.764706   5.341880
# 16    Dipika   9.117647   5.854701
# 17  Priyanka   9.411765   5.769231
# 18      Nick  10.000000   5.811966
# 19      Alia   8.823529   6.495726
# 20       Sid   9.411765   6.581197
# 21     Abdul   8.823529   5.555556

# %%
#Applying Standard Scaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df_scaled[column] = scaler.fit_transform(features.values)
df_scaled
# Out:
#         Name       Age  Income($)
# 0        Rob -1.356055  -0.480684
# 1    Michael -1.009157  -0.010159
# 2      Mohan -1.009157  -0.692421
# 3     Ismail -1.182606  -0.715947
# 4       Kory  1.245679   1.401417
# 5     Gautam  0.725332   1.519048
# 6      David  1.072230   1.636679
# 7     Andrea  0.551883   1.683732
# 8       Brad  0.204985   1.542574
# 9   Angelina  0.031536   0.930891
# 10    Donald  0.378434   1.095575
# 11       Tom -1.529504  -1.068841
# 12    Arnold -1.356055  -0.998262
# 13     Jared -1.182606  -0.927683
# 14     Stark -1.009157  -0.962973
# 15    Ranbir -0.488811  -0.880631
# 16    Dipika  0.898781  -0.598316
# 17  Priyanka  1.072230  -0.645368
# 18      Nick  1.419128  -0.621842
# 19      Alia  0.725332  -0.245422
# 20       Sid  1.072230  -0.198369
# 21     Abdul  0.725332  -0.762999

# %%
df_scaled.describe()
# Out:
#                 Age     Income($)
# count  2.200000e+01  2.200000e+01
# mean  -3.482063e-16  1.059758e-16
# std    1.023533e+00  1.023533e+00
# min   -1.529504e+00 -1.068841e+00
# 25%   -1.009157e+00 -7.512363e-01
# 50%    2.917096e-01 -5.394999e-01
# 75%    8.554186e-01  1.054404e+00
# max    1.419128e+00  1.683732e+00

# %%
# Histogram
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(x=df['Income($)'], data=df )
plt.show()

# %%
#Apply Log
df['log_income'] = np.log(df['Income($)'])
df
# Out:
#         Name  Age  Income($)  log_income
# 0        Rob   27      70000   11.156251
# 1    Michael   29      90000   11.407565
# 2      Mohan   29      61000   11.018629
# 3     Ismail   28      60000   11.002100
# 4       Kory   42     150000   11.918391
# 5     Gautam   39     155000   11.951180
# 6      David   41     160000   11.982929
# 7     Andrea   38     162000   11.995352
# 8       Brad   36     156000   11.957611
# 9   Angelina   35     130000   11.775290
# 10    Donald   37     137000   11.827736
# 11       Tom   26      45000   10.714418
# 12    Arnold   27      48000   10.778956
# 13     Jared   28      51000   10.839581
# 14     Stark   29      49500   10.809728
# 15    Ranbir   32      53000   10.878047
# 16    Dipika   40      65000   11.082143
# 17  Priyanka   41      63000   11.050890
# 18      Nick   43      64000   11.066638
# 19      Alia   39      80000   11.289782
# 20       Sid   41      82000   11.314475
# 21     Abdul   39      58000   10.968198

# %%
df['log_income'].plot.hist(bins =5)
# Out:
# <Axes: ylabel='Frequency'>
